# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df=pd.read_csv('E:\\project csv files\\sample_superstore\\SampleSuperstoreRaw.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
print('Duplicates Removed')
# Out:
# Duplicates Removed

# %%
df.shape
# Out:
# (9977, 13)

# %%
df['Profit Margin']=df['Profit']/df['Sales']*100
df['Profit Margin']=df['Profit Margin'].round(2)
df['Profit']=df['Profit'].round(2)

# %%
df['Discounted Price']=df['Sales']*(1-df['Discount'])
df['Discounted Price']=df['Discounted Price'].round(2)

# %%
df["Sales Status"] = df["Profit"].map(
    lambda x: "Profit" if x > 0 else "Loss"
)

# %%
df[['Profit Margin','Profit','Discounted Price','Discount','Sales Status']].head()
# Out:
#    Profit Margin  Profit  Discounted Price  Discount Sales Status
# 0          16.00   41.91            261.96      0.00       Profit
# 1          30.00  219.58            731.94      0.00       Profit
# 2          47.00    6.87             14.62      0.00       Profit
# 3         -40.00 -383.03            526.67      0.45         Loss
# 4          11.25    2.52             17.89      0.20       Profit

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount  Profit  Profit Margin  Discounted Price Sales Status
# ...

# %%
df.to_csv('E:\\project csv files\\sample_superstore\\SampleSuperstorecleaned.csv',header=True,mode='w')

# %%
import pandas as pd
from sqlalchemy import create_engine
result = pd.read_csv('E:\\project csv files\\sample_superstore\\SampleSuperstorecleaned.csv')
engine = create_engine( "mysql+pymysql://root:pass123@localhost:3306/mathi")
result.to_sql(
    name='samplesuperstore',   # table name (use lowercase to avoid case sensitivity issues)
    con=engine,
    if_exists='replace',       # replace if table already exists
    index=False                # don’t write DataFrame index as a column
)
# Out:
# 9994
